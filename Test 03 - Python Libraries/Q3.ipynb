# %% [markdown]
# ![image.png](attachment:1c77bad9-ab8b-4e8f-a7f2-19265a71ea15.png)

# %% [markdown]
# ![image.png](attachment:b52e4c23-103a-4cec-8c86-0099baea3e31.png)

# %%
###### Part 1 / Task 3
print(f'------------------- Question 3-------------------  ')

print(f'# Question number 1 -> (NaN) תשובה נכונה: ב. מוחקת שורות שמכילות ערכים חסרים✅')
print(f'## Question number 2 -> city תשובה נכונה: ג. מחזיר את מספר הערכים השונים בעמודה ✅')
print(f'### Question number 3 -> לפי מפת המרה gender תשובה נכונה: ב. מחליף את ערכי העמודה ✅')
print(f'#### Question number 4 ->  תשובה נכונה: ג. בוחר 5 שורות אקראיות מהטבלה✅')
print(f'##### Question number 5 -> עם אפס score תשובה נכונה: ג. ממלא את הערכים החסרים בעמודה✅')
print(f'###### Question number 6 ->  תשובה נכונה: ג. מוחקת שורות כפולות בטבלה✅')
print(f'####### Question number 7 ->  price תשובה נכונה: ד. מחזיר את 3 הערכים הגדולים ביותר בעמודת✅')
print(f'######## Question number 8 -> city תשובה נכונה: ב. מחזיר את מספר החופעות של כל ערך בעמודה✅')
print(f'######### Question number 9 -> לפי תנאי True/False תשובה נכונה: ג. יוצר סדרה בוליאנית של✅')
print(f'########## Question number 10 -> תשובה נכונה: א. מחלק את הטבלה לפי קטגוריה ומחשב ממוצע לעמודות מספריות✅')
# Out:
# ------------------- Question 3-------------------
# # Question number 1 -> (NaN) תשובה נכונה: ב. מוחקת שורות שמכילות ערכים חסרים✅
# ## Question number 2 -> city תשובה נכונה: ג. מחזיר את מספר הערכים השונים בעמודה ✅
# ### Question number 3 -> לפי מפת המרה gender תשובה נכונה: ב. מחליף את ערכי העמודה ✅
# #### Question number 4 ->  תשובה נכונה: ג. בוחר 5 שורות אקראיות מהטבלה✅
# ##### Question number 5 -> עם אפס score תשובה נכונה: ג. ממלא את הערכים החסרים בעמודה✅
# ###### Question number 6 ->  תשובה נכונה: ג. מוחקת שורות כפולות בטבלה✅
# ####### Question number 7 ->  price תשובה נכונה: ד. מחזיר את 3 הערכים הגדולים ביותר בעמודת✅
# ######## Question number 8 -> city תשובה נכונה: ב. מחזיר את מספר החופעות של כל ערך בעמודה✅
# ######### Question number 9 -> לפי תנאי True/False תשובה נכונה: ג. יוצר סדרה בוליאנית של✅
# ########## Question number 10 -> תשובה נכונה: א. מחלק את הטבלה לפי קטגוריה ומחשב ממוצע לעמודות מספריות✅
