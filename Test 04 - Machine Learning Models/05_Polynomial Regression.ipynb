# %% [markdown]
# ![image.png](attachment:40d80913-225a-43ad-bf71-00c4363b69c2.png)

# %% [markdown]
# ![image.png](attachment:a7a04841-744f-45ce-b912-e53a6533f5e0.png)

# %%
print(f'-----Qustion 5-----:\n')

R2 = 0.94
n = 10
p = 3
numerator = (1 - R2) * (n - 1)
denominator = n - p - 1
R2_adjustes = 1 - (numerator / denominator)
print(f'R2 -> {R2}')
print(f'R2_adjustes -> {R2_adjustes:.2f}')
# Out:
# -----Qustion 5-----:
#
# R2 -> 0.94
# R2_adjustes -> 0.91

# %% [markdown]
# ![image.png](attachment:25ab0183-f8a5-44aa-9394-0c4f816bd752.png)

# %%
print(f'-----Qustion 6-----:\n')
print(f'the answer is -> B')
# Out:
# -----Qustion 6-----:
#
# the answer is -> B

# %% [markdown]
# ![image.png](attachment:5ff18819-a232-48a0-b242-adc99dc3c1b3.png)

# %%
print(f'-----Qustion 7-----:\n')
# Out:
# -----Qustion 7-----:

# %% [markdown]
# Adjusted R² tells us how well the model works, while also considering how many features it uses.
# A model can get a higher regular R² just by adding more features, such as x2 and x3.
# Adjusted R² helps us check whether those extra features actually improve the model.
