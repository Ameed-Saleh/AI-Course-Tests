# %% [markdown]
# ![image.png](attachment:e75c2d33-928a-4496-85be-086140fe726e.png)

# %% [markdown]
# ![image.png](attachment:ff8cd994-2dc9-4cda-99b7-8c5c538e8517.png)

# %%
print(f'----Quetion 11----\n')
print(f'(a):')


customer = ["A", "B", "New"]
support_tickets = [2, 9, 6]
usage_hours = [80, 15, 40]
cancelled = ["No", "Yes", "?"]


min_tickets = 0
max_tickets = 10
tickets_range = max_tickets - min_tickets

tickets_scaled = []
for num in [2, 9, 6]:
    tickets_scaled.append((num - min_tickets) / tickets_range)
    
min_usage = 0
max_usage = 100
usage_range = max_usage - min_usage

usage_scaled = []
for num in [80, 15, 40]:
    usage_scaled.append((num - min_usage) / usage_range)

print(f'                 A    B   New ')
print(f'tickets_scaled {tickets_scaled}')
print(f'usage_scaled   {usage_scaled}')

print(f'\n(b):')

distance_to_a = ((tickets_scaled[2] - tickets_scaled[0]) ** 2+ (usage_scaled[2] - usage_scaled[0]) ** 2) ** 0.5
distance_to_b = ((tickets_scaled[2] - tickets_scaled[1]) ** 2+ (usage_scaled[2] - usage_scaled[1]) ** 2) ** 0.5

print(f"Distance(New, A) = {distance_to_a:.3f}")  # 0.566
print(f"Distance(New, B) = {distance_to_b:.3f}")  # 0.391


print(f'\n(b):')
# With k=1
print(f'The New customer is closer to B because {distance_to_b:.3f} < {distance_to_a:.3f}, Therefore, its predicted classification is "Yes"')
# Out:
# ----Quetion 11----
#
# (a):
#                  A    B   New
# tickets_scaled [0.2, 0.9, 0.6]
# usage_scaled   [0.8, 0.15, 0.4]
#
# (b):
# Distance(New, A) = 0.566
# Distance(New, B) = 0.391
#
# (b):
# The New customer is closer to B because 0.391 < 0.566, Therefore, its predicted classification is "Yes"

# %% [markdown]
# ![image.png](attachment:e8d376d7-103c-46f6-b1ca-589a1c23426e.png)

# %%
print(f'----Quetion 12----\n')
print(f'Use an odd k such as (k=3), to get a majority vote. Alternatively, give more weight to closer neighbours.')
# Out:
# ----Quetion 12----
#
# Use an odd k such as (k=3), to get a majority vote. Alternatively, give more weight to closer neighbours.
